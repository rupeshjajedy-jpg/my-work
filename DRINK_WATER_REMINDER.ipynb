# %% [markdown]
# <a href="https://colab.research.google.com/github/rupeshjajedy-jpg/my-work/blob/main/DRINK_WATER_REMINDER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
# !pip install plyer
# Out:
# Collecting plyer
#   Downloading plyer-2.1.0-py2.py3-none-any.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 2.2 MB/s eta 0:00:00
# Downloading plyer-2.1.0-py2.py3-none-any.whl (142 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.3/142.3 kB 6.7 MB/s eta 0:00:00
# Installing collected packages: plyer
# Successfully installed plyer-2.1.0

# %%
from plyer import notification

# %%
while True:
  print("please sip some water!")
  notification.notify(title="Please drink some water",
                      message = "You need to drink some water",)
  time.sleep(60*60)
